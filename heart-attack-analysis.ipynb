# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/heart-attack-analysis-prediction-dataset/o2Saturation.csv
# /kaggle/input/heart-attack-analysis-prediction-dataset/heart.csv

# %% [markdown]
# **#Task 10
# Leela Satya Kartheek Raja
# Register Id : SIRSS1038SIRSS1038**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
# %matplotlib inline

# %%
df = pd.read_csv('/kaggle/input/heart-attack-analysis-prediction-dataset/heart.csv')

# %%
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', len(df.columns))

# %%
df.shape
# Out:
# (303, 14)

# %%
df.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# 5    0      1       1
# 6    0      2       1
# 7    0      3       1
# 8    0      3       1
# 9    0      2       1

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall      output
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
for i in df.columns:
    print('{}:- {}\n{}\n\n'.format(i, df[i].nunique(), df[i].unique()))
# Out:
# age:- 41
# [63 37 41 56 57 44 52 54 48 49 64 58 50 66 43 69 59 42 61 40 71 51 65 53
#  46 45 39 47 62 34 35 29 55 60 67 68 74 76 70 38 77]
#
#
# sex:- 2
# [1 0]
#
#
# cp:- 4
# [3 2 1 0]
#
#
# trtbps:- 49
# [145 130 120 140 172 150 110 135 160 105 125 142 155 104 138 128 108 134
#  122 115 118 100 124  94 112 102 152 101 132 148 178 129 180 136 126 106
#  156 170 146 117 200 165 174 192 144 123 154 114 164]
#
#
# chol:- 152
# [233 250 204 236 354 192 294 263 199 168 239 275 266 211 283 219 340 226
#  247 234 243 302 212 175 417 197 198 177 273 213 304 232 269 360 308 245
#  208 264 321 325 235 257 216 256 231 141 252 201 222 260 182 303 265 309
#  186 203 183 220 209 258 227 261 221 205 240 318 298 564 277 214 248 255
#  207 223 288 160 394 315 246 244 270 195 196 254 126 313 262 215 193 271
#  268 267 210 295 306 178 242 180 228 149 278 253 342 157 286 229 284 224
#  206 167 230 335 276 353 225 330 290 172 305 188 282 185 326 274 164 307
#  249 341 407 217 174 281 289 322 299 300 293 184 409 259 200 327 237 218
#  319 166 311 169 187 176 241 131]
#
#
# fbs:- 2
# [1 0]
#
#
# restecg:- 3
# [0 1 2]
#
#
# thalachh:- 91
# [150 187 172 178 163 148 153 173 162 174 160 139 171 144 158 114 151 161
#  179 137 157 123 152 168 140 188 125 170 165 142 180 143 182 156 115 149
#  146 175 186 185 159 130 190 132 147 154 202 166 164 184 122 169 138 111
#  145 194 131 133 155 167 192 121  96 126 105 181 116 108 129 120 112 128
#  109 113  99 177 141 136  97 127 103 124  88 195 106  95 117  71 118 134
#   90]
#
#
# exng:- 2
# [0 1]
#
#
# oldpeak:- 40
# [2.3 3.5 1.4 0.8 0.6 0.4 1.3 0.  0.5 1.6 1.2 0.2 1.8 1.  2.6 1.5 3.  2.4
#  0.1 1.9 4.2 1.1 2.  0.7 0.3 0.9 3.6 3.1 3.2 2.5 2.2 2.8 3.4 6.2 4.  5.6
#  2.9 2.1 3.8 4.4]
#
#
# slp:- 3
# [0 2 1]
#
#
# caa:- 5
# [0 2 1 3 4]
#
#
# thall:- 4
# [1 2 3 0]
#
#
# output:- 2
# [1 0]

# %%
# Distributions of columns 
for i in df.columns:
    plt.hist(df[i], bins = 30, color = '#0F044C', edgecolor = 'black', rwidth = 0.8, alpha = 0.7)
    plt.title('{} Distribution\n'.format(i.title()), fontsize = 28)
    plt.xlabel('\n{}'.format(i.title()), fontsize = 22)
    plt.ylabel('Frequency\n', fontsize = 22)
    plt.show()

# %%
class Outliers(object):
    def __init__(self, df, col):
        self.df = df
        self.col = col
        
        self.mean = df[col].mean()
        self.median = df[col].median()
        self.min = df[col].min()
        self.max = df[col].max()
        self.std = df[col].std()
        self.quantile_25 = self.df[self.col].quantile(0.25)
        self.quantile_75 = self.df[self.col].quantile(0.75)
        
    def info(self):
        print('Mean:- {}'.format(self.mean))
        print('Median:- {}'.format(self.median))
        print('Standard Deviation:- {}'.format(self.std))
        print('Minimum value:- {}'.format(self.min))
        print('Maximum value:- {}'.format(self.max))
        print('25th quantile:- {}'.format(self.quantile_25))
        print('75th quantile:- {}'.format(self.quantile_75))
        
        des = '*' * 20
        return des
        
        
class IQR(Outliers):
    def __init__(self, df, col):
        super().__init__(df, col)
        
    def iqr_calc(self):
        
        IQR = self.quantile_75 - self.quantile_25
        
        lower_bound = self.quantile_25 - (1.5 * IQR)
        upper_bound = self.quantile_75 + (1.5 * IQR)
        
        return lower_bound, upper_bound
        
    def iqr_outliers(self):
        
        lower_bound, upper_bound = self.iqr_calc()
        return self.df.loc[(self.df[self.col] < lower_bound) | (self.df[self.col] > upper_bound), self.col]
        
    def iqr_remove(self):
        
        lower_bound, upper_bound = self.iqr_calc()
        return self.df.loc[(self.df[self.col] > lower_bound) & (self.df[self.col] < upper_bound)]
        
    

class Z_score(Outliers):
    def __init__(self, df, col):
        super().__init__(df, col)
        
    def z_score_outliers(self):
        outlier = []
        for i in self.df[self.col]:
            z = (i - self.mean) / self.std
            if abs(z) > 3:
                outlier.append(i)
        
        return outlier
    
    def z_score_remove(self):
        
        df_copy = self.df.copy()
        for i in self.z_score_outliers():
            df_copy = df_copy.loc[df_copy[self.col] != i]
            
        return df_copy
    

class StandardDeviation(Outliers):
    def __init__(self, df, col):
        super().__init__(df, col)
        
    def std_calc(self):
        
        lower_std = self.mean - (3 * self.std)
        upper_std = self.mean + (3 * self.std)
        
        return lower_std, upper_std
        
    def std_outliers(self):
        
        lower_std, upper_std = self.std_calc()
        return self.df.loc[(self.df[self.col] < lower_std) | (self.df[self.col] > upper_std), self.col]
    
    def std_remove(self):
        
        lower_std, upper_std = self.std_calc()
        return self.df.loc[(self.df[self.col] > lower_std) & (self.df[self.col] < upper_std)]

# %%
columns = ['chol', 'trtbps', 'thalachh', 'oldpeak']


for i in columns:
    out = Outliers(df, i)
    iqr = IQR(df, i)
    z_score = Z_score(df, i)
    std = StandardDeviation(df, i)    

    print('Outliers:- {}\n'.format(i))

    print('Info:- \n')
    out.info()
    print('*'*40)
    print('\n')
    
    
    print('IQR Outliers:- \n{}\n'.format(iqr.iqr_outliers())) 
    print('Shape of df if removed outliers with IQR:- {}'.format(iqr.iqr_remove().shape))
    print('*'*20)
    
    print('Z-score Outliers:- \n{}\n'.format(z_score.z_score_outliers())) 
    print('Shape of df if removed outliers with Z-score:- {}'.format(z_score.z_score_remove().shape))
    print('*'*20)
    
    print('StandardDeviation Outliers:- \n{}\n'.format(std.std_outliers())) 
    print('Shape of df if removed outliers with StandardDeviation:- {}'.format(std.std_remove().shape))
    
    print('\n', '*'*100, '\n', '*'*100, '\n', '*'*100, '\n')
# Out:
# Outliers:- chol
#
# Info:-
#
# Mean:- 246.26402640264027
# Median:- 240.0
# Standard Deviation:- 51.830750987930045
# Minimum value:- 126
# Maximum value:- 564
# 25th quantile:- 211.0
# 75th quantile:- 274.5
# ****************************************
#
#
# IQR Outliers:-
# 28     417
# 85     564
# 96     394
# 220    407
# 246    409
# Name: chol, dtype: int64
#
# Shape of df if removed outliers with IQR:- (298, 14)
# ********************
# Z-score Outliers:-
# [417, 564, 407, 409]
#
# Shape of df if removed outliers with Z-score:- (299, 14)
# ********************
# StandardDeviation Outliers:-
# 28     417
# 85     564
# 220    407
# 246    409
# Name: chol, dtype: int64
#
# Shape of df if removed outliers with StandardDeviation:- (299, 14)
#
#  ****************************************************************************************************
#  ****************************************************************************************************
#  ****************************************************************************************************
#
# Outliers:- trtbps
#
# Info:-
#
# Mean:- 131.62376237623764
# Median:- 130.0
# Standard Deviation:- 17.53814281351709
# Minimum value:- 94
# Maximum value:- 200
# 25th quantile:- 120.0
# 75th quantile:- 140.0
# ****************************************
#
#
# IQR Outliers:-
# 8      172
# 101    178
# 110    180
# 203    180
# 223    200
# 241    174
# 248    192
# 260    178
# 266    180
# Name: trtbps, dtype: int64
#
# Shape of df if removed outliers with IQR:- (290, 14)
# ********************
# Z-score Outliers:-
# [200, 192]
#
# Shape of df if removed outliers with Z-score:- (301, 14)
# ********************
# StandardDeviation Outliers:-
# 223    200
# 248    192
# Name: trtbps, dtype: int64
#
# Shape of df if removed outliers with StandardDeviation:- (301, 14)
#
#  ****************************************************************************************************
#  ****************************************************************************************************
#  ****************************************************************************************************
#
# Outliers:- thalachh
#
# Info:-
#
# Mean:- 149.64686468646866
# Median:- 153.0
# Standard Deviation:- 22.905161114914087
# Minimum value:- 71
# Maximum value:- 202
# 25th quantile:- 133.5
# 75th quantile:- 166.0
# ****************************************
#
#
# IQR Outliers:-
# 272    71
# Name: thalachh, dtype: int64
#
# Shape of df if removed outliers with IQR:- (302, 14)
# ********************
# Z-score Outliers:-
# [71]
#
# Shape of df if removed outliers with Z-score:- (302, 14)
# ********************
# StandardDeviation Outliers:-
# 272    71
# Name: thalachh, dtype: int64
#
# Shape of df if removed outliers with StandardDeviation:- (302, 14)
#
#  ****************************************************************************************************
#  ****************************************************************************************************
#  ****************************************************************************************************
#
# Outliers:- oldpeak
#
# Info:-
#
# Mean:- 1.0396039603960396
# Median:- 0.8
# Standard Deviation:- 1.1610750220686343
# Minimum value:- 0.0
# Maximum value:- 6.2
# 25th quantile:- 0.0
# 75th quantile:- 1.6
# ****************************************
#
#
# IQR Outliers:-
# 101    4.2
# 204    6.2
# 221    5.6
# 250    4.2
# 291    4.4
# Name: oldpeak, dtype: float64
#
# Shape of df if removed outliers with IQR:- (295, 14)
# ********************
# Z-score Outliers:-
# [6.2, 5.6]
#
# Shape of df if removed outliers with Z-score:- (301, 14)
# ********************
# StandardDeviation Outliers:-
# 204    6.2
# 221    5.6
# Name: oldpeak, dtype: float64
#
# Shape of df if removed outliers with StandardDeviation:- (301, 14)
#
#  ****************************************************************************************************
#  ****************************************************************************************************
#  ****************************************************************************************************

# %%
##### Treating Outliers of chol
z_score_chol = Z_score(df, 'chol')
df = z_score_chol.z_score_remove()

# %%
##### Treating Outliers of thalachh
iqr_thalachh = IQR(df, 'thalachh')
df = iqr_thalachh.iqr_remove()

# %%
##### Treating Outliers of oldpeak
z_score_oldpeak = Z_score(df, 'oldpeak')
df = z_score_oldpeak.z_score_remove()

# %%
df.shape
# Out:
# (296, 14)

# %%
# Distributions of columns aftet treating outliers
for i in df.columns:
    plt.hist(df[i], bins = 30, color = '#0F044C', edgecolor = 'black', rwidth = 0.8, alpha = 0.7)
    plt.title('{} Distribution\n'.format(i.title()), fontsize = 25)
    plt.xlabel('\n{}'.format(i.title()), fontsize = 20)
    plt.ylabel('Frequency\n', fontsize = 20)
    plt.show()

# %% [markdown]
# ** EDA ANALYSIS ON DATA SET**

# %%
sex_out = df.groupby(['sex', 'output'])[['output']].count()

#idx = pd.IndexSlice
#sex_out.loc[idx[0, :], :].output

indx = np.arange(len(sex_out.unstack().output.index))
width = 0.25


plt.bar(indx - width/2, sex_out.unstack().output[0].values,
        width = width, alpha = 0.7, edgecolor = 'black', label = 'less chance of heart attack')
plt.bar(indx + width/2, sex_out.unstack().output[1].values,
        width = width, alpha = 0.7, edgecolor = 'black', label = 'more chance of heart attack')

plt.title('Frequency of people with chance of heart attack \n(gender wise)\n', fontsize = 25)
plt.xlabel('\nSex', fontsize = 20)
plt.ylabel('Frequency\n', fontsize = 20)


plt.xticks([0,1], ['Female', 'Male'])
plt.legend(frameon = True, facecolor = 'gray', framealpha = 0.2, shadow = False, fontsize = 12.5)
plt.show()

# %%
sex_atk = df.groupby('sex')[['output']].mean()

plt.bar(sex_atk.index.map({0: 'Female', 1: 'Male'}), sex_atk.output, color = 'red', 
        alpha = 0.5, edgecolor = 'black', width = 0.5)

plt.title('Chance of getting heart attack of each gender type\n', fontsize = 25)
plt.xlabel('\nChance of getting heart attack (in %)', fontsize = 20)
plt.ylabel('Genders\n', fontsize = 20)
plt.show()

# %%
sex_hrt = df.groupby('sex')[['output']].mean()

plt.pie(sex_hrt.output, labels = sex_hrt.index.map({0: 'Female', 1: 'Male'}), wedgeprops = {'edgecolor': 'black'}, 
        shadow = True, textprops = {'fontsize': 15}, autopct = '%1.2f%%')
plt.title('Chance of getting (if compared according to genders)', fontsize = 20)
plt.show()

# %%
sex_info = df.groupby('sex')[['chol', 'trtbps', 'thalachh', 'oldpeak']].aggregate(np.mean)

plt.figure(figsize = (9, 5))

indx = np.arange(len(sex_info.columns))
width = 0.2

plt.bar(indx - width/2, sex_info.loc[0, :], width = width, alpha = 0.5, color = 'pink', label = 'Female', edgecolor = 'black')
plt.bar(indx + width/2, sex_info.loc[1, :], width = width, alpha = 0.5, color = 'blue', label = 'Male', edgecolor = 'black')

plt.title('Comparing genders on avg. values of different categories\n', fontsize = 25)
plt.xlabel('\nCategories', fontsize = 20)
plt.ylabel('Average values\n', fontsize = 20)

plt.yscale('log')
plt.xticks([0, 1, 2, 3], ['chol', 'trtbps', 'thalachh', 'oldpeak'])
plt.legend(loc = 'best', frameon = True, fontsize = 15)
plt.show()

# %%
age_dis = pd.qcut(df.age, 5)
age_hrt = df.pivot_table('output', index = age_dis, columns = 'sex')

plt.figure(figsize = (12,9))

indx = np.arange(len(age_hrt.index))
width = 0.4

plt.barh(indx - width/2, age_hrt[0], height = width, alpha = 0.7, edgecolor = 'black', label = 'Female')
plt.barh(indx + width/2, age_hrt[1], height = width, alpha = 0.7, edgecolor = 'black', label = 'Male')

plt.title('Chances of having heart attack as pereach age group\n', fontsize = 25)
plt.xlabel('\nChances of heart attack (in %)', fontsize = 20)
plt.ylabel('Age Group\n', fontsize = 20)

plt.yticks(indx, age_hrt.index)
plt.legend(fontsize = 15, frameon = True, loc = 'best')
plt.show()

# %% [markdown]
# cREATING a mODEL

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
for i in df.columns:
    print(i, ':- ', df[i].nunique())
# Out:
# age :-  41
# sex :-  2
# cp :-  4
# trtbps :-  49
# chol :-  145
# fbs :-  2
# restecg :-  3
# thalachh :-  90
# exng :-  2
# oldpeak :-  38
# slp :-  3
# caa :-  5
# thall :-  4
# output :-  2

# %%
X = df.drop('output', axis = 1).copy()
y = df['output']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((236, 13), (60, 13), (236,), (60,))

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler

# %%
cat1 = ['sex', 'fbs','exng']
cat2 = ['cp', 'restecg', 'caa', 'thall']
num = ['age', 'trtbps', 'chol', 'thalachh', 'oldpeak']

# %%
trans_col = make_column_transformer((OneHotEncoder(handle_unknown = 'ignore'), cat2), 
                                    (OrdinalEncoder(), cat1), 
                                    (StandardScaler(), num), 
                                    remainder = 'passthrough')

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
pipe_lr = make_pipeline(trans_col, LogisticRegression(solver = 'liblinear'))
pipe_svm = make_pipeline(trans_col, SVC())
pipe_rf = make_pipeline(trans_col, RandomForestClassifier())

# %%
from sklearn.model_selection import GridSearchCV

# %%
params_lr = {
    'logisticregression__penalty': ['l1', 'l2'],
    'logisticregression__tol': [0.01, 0.001, 0.0001, 0.00001]
}

grid_lr = GridSearchCV(estimator = pipe_lr, param_grid = params_lr, cv = 10, verbose = 10)

# %%
params_svm = {
    'svc__kernel': ['linear', 'rbf'],
    'svc__C': [1, 10, 100, 1000, 10000]
}

grid_svm = GridSearchCV(estimator = pipe_svm, param_grid = params_svm, cv = 10, verbose = 10)

# %%
params_rf = {
    'randomforestclassifier__criterion': ['entropy', 'gini'],
    'randomforestclassifier__max_depth': [2, 4, 6, 8, 10],
    'randomforestclassifier__min_samples_split': [2, 4, 6, 8, 10],
    'randomforestclassifier__min_samples_leaf': [2, 3, 4, 5]
}

grid_rf = GridSearchCV(estimator = pipe_rf, param_grid = params_rf, cv = 10, verbose = 10, n_jobs = -1)

# %%
grid_lr.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.01, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.3s remaining:    0.0s
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l1, logisticregression__tol=0.0001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l1, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l1, logisticregression__tol=1e-05, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.833, total=   0.2s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.917, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.01 ....
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.01, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.917, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.001 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.917, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=0.0001 ..
# [CV]  logisticregression__penalty=l2, logisticregression__tol=0.0001, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.917, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.875, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.833, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.792, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.870, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.826, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.913, total=   0.0s
# [CV] logisticregression__penalty=l2, logisticregression__tol=1e-05 ...
# [CV]  logisticregression__penalty=l2, logisticregression__tol=1e-05, score=0.826, total=   0.0s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:    2.5s finished
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['cp',
#                                                                           'restecg',
#                                                                           'caa',
#                                                                           'thall']),
#                                                                         ('ordinalencoder',
#                                                                          OrdinalEncoder(),
#                                                                          ['sex',
#                                                                           'fbs',
#                                                                           'exng']),
#                                                                         ('standardscaler',
#                                                                          StandardScaler(),
#                                                                          ['age',
#                                                                           'trtbps',
#                                                                           'chol',
#                                                                           'thalachh',
#                                                                           'oldpeak'])])),
#                                        ('logisticregression',
#                                         LogisticRegression(solver='liblinear'))]),
#              param_grid={'logisticregression__penalty': ['l1', 'l2'],
#                          'logisticregression__tol': [0.01, 0.001, 0.0001,
#                                                      1e-05]},
#              verbose=10)

# %%
grid_svm.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] svc__C=1, svc__kernel=linear ....................................
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.708, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.833, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.833, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.792, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.792, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.792, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.826, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.783, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.913, total=   0.0s
# [CV] svc__C=1, svc__kernel=linear ....................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.3s remaining:    0.0s
# [CV] ........ svc__C=1, svc__kernel=linear, score=0.826, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.750, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.792, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.875, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.792, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.792, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.792, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.870, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.826, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.870, total=   0.0s
# [CV] svc__C=1, svc__kernel=rbf .......................................
# [CV] ........... svc__C=1, svc__kernel=rbf, score=0.826, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.750, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.833, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.792, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.792, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.750, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.792, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.826, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.826, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.913, total=   0.0s
# [CV] svc__C=10, svc__kernel=linear ...................................
# [CV] ....... svc__C=10, svc__kernel=linear, score=0.826, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.708, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.833, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.792, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.792, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.792, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.750, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.783, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.739, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.783, total=   0.0s
# [CV] svc__C=10, svc__kernel=rbf ......................................
# [CV] .......... svc__C=10, svc__kernel=rbf, score=0.739, total=   0.0s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.708, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.833, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.792, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.792, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.750, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.792, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.826, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.826, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.957, total=   0.1s
# [CV] svc__C=100, svc__kernel=linear ..................................
# [CV] ...... svc__C=100, svc__kernel=linear, score=0.826, total=   0.1s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.708, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.875, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.833, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.750, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.833, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.667, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.826, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.739, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.783, total=   0.0s
# [CV] svc__C=100, svc__kernel=rbf .....................................
# [CV] ......... svc__C=100, svc__kernel=rbf, score=0.739, total=   0.0s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.708, total=   0.4s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.833, total=   0.7s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.792, total=   0.9s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.792, total=   0.6s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.750, total=   0.3s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.792, total=   0.3s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.826, total=   0.4s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.826, total=   0.4s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.957, total=   0.3s
# [CV] svc__C=1000, svc__kernel=linear .................................
# [CV] ..... svc__C=1000, svc__kernel=linear, score=0.826, total=   4.3s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.708, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.875, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.833, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.750, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.833, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.667, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.826, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.739, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.783, total=   0.0s
# [CV] svc__C=1000, svc__kernel=rbf ....................................
# [CV] ........ svc__C=1000, svc__kernel=rbf, score=0.739, total=   0.0s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.708, total=   5.2s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.833, total=   5.5s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.792, total=   4.2s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.792, total=   3.5s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.750, total=   6.1s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.792, total=   8.9s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.826, total=   3.9s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.826, total=   2.8s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.957, total=   7.7s
# [CV] svc__C=10000, svc__kernel=linear ................................
# [CV] .... svc__C=10000, svc__kernel=linear, score=0.870, total=  26.9s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.708, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.875, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.833, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.750, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.833, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.667, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.826, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.739, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.783, total=   0.0s
# [CV] svc__C=10000, svc__kernel=rbf ...................................
# [CV] ....... svc__C=10000, svc__kernel=rbf, score=0.739, total=   0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  1.4min finished
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['cp',
#                                                                           'restecg',
#                                                                           'caa',
#                                                                           'thall']),
#                                                                         ('ordinalencoder',
#                                                                          OrdinalEncoder(),
#                                                                          ['sex',
#                                                                           'fbs',
#                                                                           'exng']),
#                                                                         ('standardscaler',
#                                                                          StandardScaler(),
#                                                                          ['age',
#                                                                           'trtbps',
#                                                                           'chol',
#                                                                           'thalachh',
#                                                                           'oldpeak'])])),
#                                        ('svc', SVC())]),
#              param_grid={'svc__C': [1, 10, 100, 1000, 10000],
#                          'svc__kernel': ['linear', 'rbf']},
#              verbose=10)

# %%
grid_rf.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   18.8s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   22.3s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   29.1s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   34.0s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   36.5s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   42.2s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   51.5s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:   58.5s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 2000 out of 2000 | elapsed:  3.5min finished
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['cp',
#                                                                           'restecg',
#                                                                           'caa',
#                                                                           'thall']),
#                                                                         ('ordinalencoder',
#                                                                          OrdinalEncoder(),
#                                                                          ['sex',
#                                                                           'fbs',
#                                                                           'exng']),
#                                                                         ('standardscaler',
#                                                                          StandardScaler(),
#                                                                          ['age',
#                                                                           'trtbps',
#                                                                           'chol',
#                                                                           'thalachh',
#                                                                           'oldpeak'])])),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'randomforestclassifier__criterion': ['entropy',
#                                                                'gini'],
#                          'randomforestclassifier__max_depth': [2, 4, 6, 8, 10],
#                          'randomforestclassifier__min_samples_leaf': [2, 3, 4,
#                                                                       5],
#                          'randomforestclassifier__min_samples_split': [2, 4, 6,
#                                                                        8, 10]},
#              verbose=10)

# %%
print(grid_lr.best_params_)
print(grid_lr.score(X_train, y_train))
print(grid_lr.score(X_test, y_test))
# Out:
# {'logisticregression__penalty': 'l2', 'logisticregression__tol': 0.01}
# 0.8728813559322034
# 0.8333333333333334

# %%
print(grid_svm.best_params_)
print(grid_svm.score(X_train, y_train))
print(grid_svm.score(X_test, y_test))
# Out:
# {'svc__C': 1, 'svc__kernel': 'rbf'}
# 0.9110169491525424
# 0.8166666666666667

# %%
print(grid_rf.best_params_)
print(grid_rf.score(X_train, y_train))
print(grid_rf.score(X_test, y_test))
# Out:
# {'randomforestclassifier__criterion': 'gini', 'randomforestclassifier__max_depth': 4, 'randomforestclassifier__min_samples_leaf': 2, 'randomforestclassifier__min_samples_split': 10}
# 0.8940677966101694
# 0.85

# %%
from sklearn.metrics import f1_score

# %%
print(f1_score(y_test, grid_lr.predict(X_test)))
print(f1_score(y_test, grid_svm.predict(X_test)))
print(f1_score(y_test, grid_rf.predict(X_test)))
# Out:
# 0.8387096774193549
# 0.8253968253968254
# 0.8524590163934426

# %%
df.to_csv('result1.csv',index=False)
